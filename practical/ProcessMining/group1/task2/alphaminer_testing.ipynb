# %% [markdown]
# # Alpha Miner Testing with Simple Event Logs

# %%
# %reload_ext autoreload
# %autoreload 2
from practical.ProcessMining.group1.task2.alphaminer import AlphaMiner
from practical.ProcessMining.group1.shared import utils

logs = utils.read_txt_test_logs('../shared/example_files/simple_event_logs.txt')

def get_log_output(event_logs, log_key):
    L = utils.deduplicate_list(event_logs[log_key])
    miner = AlphaMiner(utils.event_log_to_csv(L))
    print(f'{log_key}: {L}\n')
    print(miner.footprint_matrix(), '\n')
    miner.print_pairs()
    miner.build_and_visualize_petrinet()

# %%
get_log_output(logs, 'L1')
# Out:
# L1: [('a', 'b', 'c', 'd'), ('a', 'c', 'b', 'd'), ('a', 'e', 'd')]
#
#    a   b   c  d  e
# a  #   →   →  #  →
# b  ←   #  ||  →  #
# c  ←  ||   #  →  #
# d  #   ←   ←  #  ←
# e  ←   #   #  →  #
#
# Following pairs:
# [({'a'}, {'b'}), ({'b'}, {'c'}), ({'a'}, {'e'}), ({'c'}, {'b'}), ({'e'}, {'d'}), ({'c'}, {'d'}), ({'a'}, {'c'}), ({'b'}, {'d'})]
#
# Parallel pairs:
# [({'b'}, {'c'}), ({'c'}, {'b'})]
#
# Sequential pairs:
# [({'a'}, {'b'}), ({'a'}, {'e'}), ({'e'}, {'d'}), ({'c'}, {'d'}), ({'a'}, {'c'}), ({'b'}, {'d'})]
#
# Not following pairs:
# [({'a'}, {'a'}), ({'a'}, {'d'}), ({'b'}, {'b'}), ({'b'}, {'e'}), ({'c'}, {'c'}), ({'c'}, {'e'}), ({'d'}, {'a'}), ({'d'}, {'d'}), ({'e'}, {'b'}), ({'e'}, {'c'}), ({'e'}, {'e'})]
#
# Before pairs:
# [({'b'}, {'a'}), ({'c'}, {'a'}), ({'d'}, {'b'}), ({'d'}, {'c'}), ({'d'}, {'e'}), ({'e'}, {'a'})]
#
# Maximal pairs:
# [({'a'}, {'b', 'e'}), ({'a'}, {'c', 'e'}), ({'c', 'e'}, {'d'}), ({'b', 'e'}, {'d'})]

# %%
get_log_output(logs, 'L2')
# Out:
# L2: [('a', 'c', 'b', 'e', 'f', 'b', 'c', 'd'), ('a', 'b', 'c', 'e', 'f', 'c', 'b', 'd'), ('a', 'b', 'c', 'e', 'f', 'b', 'c', 'd'), ('a', 'c', 'b', 'd'), ('a', 'b', 'c', 'd'), ('a', 'c', 'b', 'e', 'f', 'b', 'c', 'e', 'f', 'c', 'b', 'd')]
#
#    a   b   c  d  e  f
# a  #   →   →  #  #  #
# b  ←   #  ||  →  →  ←
# c  ←  ||   #  →  →  ←
# d  #   ←   ←  #  #  #
# e  #   ←   ←  #  #  →
# f  #   →   →  #  ←  #
#
# Following pairs:
# [({'a'}, {'b'}), ({'c'}, {'e'}), ({'b'}, {'c'}), ({'c'}, {'b'}), ({'f'}, {'b'}), ({'b'}, {'e'}), ({'c'}, {'d'}), ({'a'}, {'c'}), ({'e'}, {'f'}), ({'b'}, {'d'}), ({'f'}, {'c'})]
#
# Parallel pairs:
# [({'b'}, {'c'}), ({'c'}, {'b'})]
#
# Sequential pairs:
# [({'a'}, {'b'}), ({'c'}, {'e'}), ({'f'}, {'b'}), ({'b'}, {'e'}), ({'c'}, {'d'}), ({'a'}, {'c'}), ({'e'}, {'f'}), ({'b'}, {'d'}), ({'f'}, {'c'})]
#
# Not following pairs:
# [({'a'}, {'a'}), ({'a'}, {'d'}), ({'a'}, {'e'}), ({'a'}, {'f'}), ({'b'}, {'b'}), ({'c'}, {'c'}), ({'d'}, {'a'}), ({'d'}, {'d'}), ({'d'}, {'e'}), ({'d'}, {'f'}), ({'e'}, {'a'}), ({'e'}, {'d'}), ({'e'}, {'e'}), ({'f'}, {'a'}), ({'f'}, {'d'}), ({'f'}, {'f'})]
#
# Before pairs:
# [({'b'}, {'a'}), ({'b'}, {'f'}), ({'c'}, {'a'}), ({'c'}, {'f'}), ({'d'}, {'b'}), ({'d'}, {'c'}), ({'e'}, {'b'}), ({'e'}, {'c'}), ({'f'}, {'e'})]
#
# Maximal pairs:
# [({'f', 'a'}, {'c'}), ({'b'}, {'d', 'e'}), ({'f', 'a'}, {'b'}), ({'e'}, {'f'}), ({'c'}, {'d', 'e'})]

# %%
get_log_output(logs, 'L3')
# Out:
# L3: [('a', 'b', 'c', 'd', 'e', 'f', 'b', 'd', 'c', 'e', 'g'), ('a', 'b', 'd', 'c', 'e', 'g'), ('a', 'b', 'c', 'd', 'e', 'f', 'b', 'c', 'd', 'e', 'f', 'b', 'd', 'c', 'e', 'g')]
#
#    a  b   c   d  e  f  g
# a  #  →   #   #  #  #  #
# b  ←  #   →   →  #  ←  #
# c  #  ←   #  ||  →  #  #
# d  #  ←  ||   #  →  #  #
# e  #  #   ←   ←  #  →  →
# f  #  →   #   #  ←  #  #
# g  #  #   #   #  ←  #  #
#
# Following pairs:
# [({'a'}, {'b'}), ({'c'}, {'e'}), ({'b'}, {'c'}), ({'d'}, {'e'}), ({'e'}, {'g'}), ({'f'}, {'b'}), ({'c'}, {'d'}), ({'e'}, {'f'}), ({'d'}, {'c'}), ({'b'}, {'d'})]
#
# Parallel pairs:
# [({'c'}, {'d'}), ({'d'}, {'c'})]
#
# Sequential pairs:
# [({'a'}, {'b'}), ({'c'}, {'e'}), ({'b'}, {'c'}), ({'d'}, {'e'}), ({'e'}, {'g'}), ({'f'}, {'b'}), ({'e'}, {'f'}), ({'b'}, {'d'})]
#
# Not following pairs:
# [({'a'}, {'a'}), ({'a'}, {'c'}), ({'a'}, {'d'}), ({'a'}, {'e'}), ({'a'}, {'f'}), ({'a'}, {'g'}), ({'b'}, {'b'}), ({'b'}, {'e'}), ({'b'}, {'g'}), ({'c'}, {'a'}), ({'c'}, {'c'}), ({'c'}, {'f'}), ({'c'}, {'g'}), ({'d'}, {'a'}), ({'d'}, {'d'}), ({'d'}, {'f'}), ({'d'}, {'g'}), ({'e'}, {'a'}), ({'e'}, {'b'}), ({'e'}, {'e'}), ({'f'}, {'a'}), ({'f'}, {'c'}), ({'f'}, {'d'}), ({'f'}, {'f'}), ({'f'}, {'g'}), ({'g'}, {'a'}), ({'g'}, {'b'}), ({'g'}, {'c'}), ({'g'}, {'d'}), ({'g'}, {'f'}), ({'g'}, {'g'})]
#
# Before pairs:
# [({'b'}, {'a'}), ({'b'}, {'f'}), ({'c'}, {'b'}), ({'d'}, {'b'}), ({'e'}, {'c'}), ({'e'}, {'d'}), ({'f'}, {'e'}), ({'g'}, {'e'})]
#
# Maximal pairs:
# [({'c'}, {'e'}), ({'b'}, {'c'}), ({'d'}, {'e'}), ({'e'}, {'f', 'g'}), ({'f', 'a'}, {'b'}), ({'b'}, {'d'})]

# %%
get_log_output(logs, 'L4')
# Out:
# L4: [('a', 'c', 'e'), ('b', 'c', 'e'), ('a', 'c', 'd'), ('b', 'c', 'd')]
#
#    a  b  c  d  e
# a  #  #  →  #  #
# b  #  #  →  #  #
# c  ←  ←  #  →  →
# d  #  #  ←  #  #
# e  #  #  ←  #  #
#
# Following pairs:
# [({'c'}, {'d'}), ({'a'}, {'c'}), ({'b'}, {'c'}), ({'c'}, {'e'})]
#
# Parallel pairs:
# []
#
# Sequential pairs:
# [({'c'}, {'d'}), ({'a'}, {'c'}), ({'b'}, {'c'}), ({'c'}, {'e'})]
#
# Not following pairs:
# [({'a'}, {'a'}), ({'a'}, {'b'}), ({'a'}, {'d'}), ({'a'}, {'e'}), ({'b'}, {'a'}), ({'b'}, {'b'}), ({'b'}, {'d'}), ({'b'}, {'e'}), ({'c'}, {'c'}), ({'d'}, {'a'}), ({'d'}, {'b'}), ({'d'}, {'d'}), ({'d'}, {'e'}), ({'e'}, {'a'}), ({'e'}, {'b'}), ({'e'}, {'d'}), ({'e'}, {'e'})]
#
# Before pairs:
# [({'c'}, {'a'}), ({'c'}, {'b'}), ({'d'}, {'c'}), ({'e'}, {'c'})]
#
# Maximal pairs:
# [({'c'}, {'d', 'e'}), ({'b', 'a'}, {'c'})]

# %%
get_log_output(logs, 'L5')
# Out:
# L5: [('a', 'b', 'e', 'c', 'd', 'b', 'f'), ('a', 'b', 'c', 'd', 'e', 'b', 'f'), ('a', 'b', 'c', 'e', 'd', 'b', 'f'), ('a', 'e', 'b', 'c', 'd', 'b', 'f'), ('a', 'b', 'e', 'f')]
#
#    a   b   c   d   e  f
# a  #   →   #   #   →  #
# b  ←   #   →   ←  ||  →
# c  #   ←   #   →  ||  #
# d  #   →   ←   #  ||  #
# e  ←  ||  ||  ||   #  →
# f  #   ←   #   #   ←  #
#
# Following pairs:
# [({'a'}, {'b'}), ({'c'}, {'e'}), ({'b'}, {'c'}), ({'a'}, {'e'}), ({'d'}, {'e'}), ({'b'}, {'f'}), ({'d'}, {'b'}), ({'e'}, {'d'}), ({'b'}, {'e'}), ({'e'}, {'c'}), ({'c'}, {'d'}), ({'e'}, {'f'}), ({'e'}, {'b'})]
#
# Parallel pairs:
# [({'c'}, {'e'}), ({'d'}, {'e'}), ({'e'}, {'d'}), ({'b'}, {'e'}), ({'e'}, {'c'}), ({'e'}, {'b'})]
#
# Sequential pairs:
# [({'a'}, {'b'}), ({'b'}, {'c'}), ({'a'}, {'e'}), ({'b'}, {'f'}), ({'d'}, {'b'}), ({'c'}, {'d'}), ({'e'}, {'f'})]
#
# Not following pairs:
# [({'a'}, {'a'}), ({'a'}, {'c'}), ({'a'}, {'d'}), ({'a'}, {'f'}), ({'b'}, {'b'}), ({'c'}, {'a'}), ({'c'}, {'c'}), ({'c'}, {'f'}), ({'d'}, {'a'}), ({'d'}, {'d'}), ({'d'}, {'f'}), ({'e'}, {'e'}), ({'f'}, {'a'}), ({'f'}, {'c'}), ({'f'}, {'d'}), ({'f'}, {'f'})]
#
# Before pairs:
# [({'b'}, {'a'}), ({'b'}, {'d'}), ({'c'}, {'b'}), ({'d'}, {'c'}), ({'e'}, {'a'}), ({'f'}, {'b'}), ({'f'}, {'e'})]
#
# Maximal pairs:
# [({'d', 'a'}, {'b'}), ({'a'}, {'e'}), ({'c'}, {'d'}), ({'e'}, {'f'}), ({'b'}, {'f', 'c'})]

# %%
get_log_output(logs, 'L6')
# Out:
# L6: [('a', 'c', 'e', 'g'), ('a', 'e', 'c', 'g'), ('b', 'f', 'd', 'g'), ('b', 'd', 'f', 'g')]
#
#    a  b   c   d   e   f  g
# a  #  #   →   #   →   #  #
# b  #  #   #   →   #   →  #
# c  ←  #   #   #  ||   #  →
# d  #  ←   #   #   #  ||  →
# e  ←  #  ||   #   #   #  →
# f  #  ←   #  ||   #   #  →
# g  #  #   ←   ←   ←   ←  #
#
# Following pairs:
# [({'c'}, {'e'}), ({'a'}, {'e'}), ({'b'}, {'f'}), ({'e'}, {'g'}), ({'e'}, {'c'}), ({'a'}, {'c'}), ({'c'}, {'g'}), ({'f'}, {'g'}), ({'d'}, {'g'}), ({'f'}, {'d'}), ({'b'}, {'d'}), ({'d'}, {'f'})]
#
# Parallel pairs:
# [({'c'}, {'e'}), ({'e'}, {'c'}), ({'f'}, {'d'}), ({'d'}, {'f'})]
#
# Sequential pairs:
# [({'a'}, {'e'}), ({'b'}, {'f'}), ({'e'}, {'g'}), ({'a'}, {'c'}), ({'c'}, {'g'}), ({'f'}, {'g'}), ({'d'}, {'g'}), ({'b'}, {'d'})]
#
# Not following pairs:
# [({'a'}, {'a'}), ({'a'}, {'b'}), ({'a'}, {'d'}), ({'a'}, {'f'}), ({'a'}, {'g'}), ({'b'}, {'a'}), ({'b'}, {'b'}), ({'b'}, {'c'}), ({'b'}, {'e'}), ({'b'}, {'g'}), ({'c'}, {'b'}), ({'c'}, {'c'}), ({'c'}, {'d'}), ({'c'}, {'f'}), ({'d'}, {'a'}), ({'d'}, {'c'}), ({'d'}, {'d'}), ({'d'}, {'e'}), ({'e'}, {'b'}), ({'e'}, {'d'}), ({'e'}, {'e'}), ({'e'}, {'f'}), ({'f'}, {'a'}), ({'f'}, {'c'}), ({'f'}, {'e'}), ({'f'}, {'f'}), ({'g'}, {'a'}), ({'g'}, {'b'}), ({'g'}, {'g'})]
#
# Before pairs:
# [({'c'}, {'a'}), ({'d'}, {'b'}), ({'e'}, {'a'}), ({'f'}, {'b'}), ({'g'}, {'c'}), ({'g'}, {'d'}), ({'g'}, {'e'}), ({'g'}, {'f'})]
#
# Maximal pairs:
# [({'a'}, {'e'}), ({'b'}, {'f'}), ({'c', 'd'}, {'g'}), ({'f', 'e'}, {'g'}), ({'d', 'e'}, {'g'}), ({'a'}, {'c'}), ({'f', 'c'}, {'g'}), ({'b'}, {'d'})]

# %%
get_log_output(logs, 'L7')
# Out:
# L7: [('a', 'b', 'b', 'b', 'b', 'c'), ('a', 'b', 'b', 'c'), ('a', 'c'), ('a', 'b', 'c')]
#
#    a   b  c
# a  #   →  →
# b  ←  ||  →
# c  ←   ←  #
#
# Following pairs:
# [({'a'}, {'b'}), ({'a'}, {'c'}), ({'b'}, {'c'}), ({'b'}, {'b'})]
#
# Parallel pairs:
# [({'b'}, {'b'})]
#
# Sequential pairs:
# [({'a'}, {'b'}), ({'a'}, {'c'}), ({'b'}, {'c'})]
#
# Not following pairs:
# [({'a'}, {'a'}), ({'c'}, {'c'})]
#
# Before pairs:
# [({'b'}, {'a'}), ({'c'}, {'a'}), ({'c'}, {'b'})]
#
# Maximal pairs:
# [({'a'}, {'c'})]

# %%
get_log_output(logs, 'L8')
# Out:
# L8: [('a', 'b', 'c', 'b', 'd'), ('a', 'b', 'c', 'b', 'c', 'b', 'd'), ('a', 'b', 'd')]
#
#    a   b   c  d
# a  #   →   #  #
# b  ←   #  ||  →
# c  #  ||   #  #
# d  #   ←   #  #
#
# Following pairs:
# [({'a'}, {'b'}), ({'b'}, {'c'}), ({'b'}, {'d'}), ({'c'}, {'b'})]
#
# Parallel pairs:
# [({'b'}, {'c'}), ({'c'}, {'b'})]
#
# Sequential pairs:
# [({'a'}, {'b'}), ({'b'}, {'d'})]
#
# Not following pairs:
# [({'a'}, {'a'}), ({'a'}, {'c'}), ({'a'}, {'d'}), ({'b'}, {'b'}), ({'c'}, {'a'}), ({'c'}, {'c'}), ({'c'}, {'d'}), ({'d'}, {'a'}), ({'d'}, {'c'}), ({'d'}, {'d'})]
#
# Before pairs:
# [({'b'}, {'a'}), ({'d'}, {'b'})]
#
# Maximal pairs:
# [({'a'}, {'b'}), ({'b'}, {'d'})]

# %%
get_log_output(logs, 'L9')
# Out:
# L9: [('b', 'c', 'e'), ('a', 'c', 'd')]
#
#    a  b  c  d  e
# a  #  #  →  #  #
# b  #  #  →  #  #
# c  ←  ←  #  →  →
# d  #  #  ←  #  #
# e  #  #  ←  #  #
#
# Following pairs:
# [({'c'}, {'d'}), ({'a'}, {'c'}), ({'b'}, {'c'}), ({'c'}, {'e'})]
#
# Parallel pairs:
# []
#
# Sequential pairs:
# [({'c'}, {'d'}), ({'a'}, {'c'}), ({'b'}, {'c'}), ({'c'}, {'e'})]
#
# Not following pairs:
# [({'a'}, {'a'}), ({'a'}, {'b'}), ({'a'}, {'d'}), ({'a'}, {'e'}), ({'b'}, {'a'}), ({'b'}, {'b'}), ({'b'}, {'d'}), ({'b'}, {'e'}), ({'c'}, {'c'}), ({'d'}, {'a'}), ({'d'}, {'b'}), ({'d'}, {'d'}), ({'d'}, {'e'}), ({'e'}, {'a'}), ({'e'}, {'b'}), ({'e'}, {'d'}), ({'e'}, {'e'})]
#
# Before pairs:
# [({'c'}, {'a'}), ({'c'}, {'b'}), ({'d'}, {'c'}), ({'e'}, {'c'})]
#
# Maximal pairs:
# [({'c'}, {'d', 'e'}), ({'b', 'a'}, {'c'})]

# %%
get_log_output(logs, 'L10')
# Out:
# L10: [('a', 'a')]
#
#     a
# a  ||
#
# Following pairs:
# [({'a'}, {'a'})]
#
# Parallel pairs:
# [({'a'}, {'a'})]
#
# Sequential pairs:
# []
#
# Not following pairs:
# []
#
# Before pairs:
# []
#
# Maximal pairs:
# []

# %%
get_log_output(logs, 'L11')
# Out:
# L11: [('a', 'c'), ('a', 'b', 'c')]
#
#    a  b  c
# a  #  →  →
# b  ←  #  →
# c  ←  ←  #
#
# Following pairs:
# [({'a'}, {'b'}), ({'a'}, {'c'}), ({'b'}, {'c'})]
#
# Parallel pairs:
# []
#
# Sequential pairs:
# [({'a'}, {'b'}), ({'a'}, {'c'}), ({'b'}, {'c'})]
#
# Not following pairs:
# [({'a'}, {'a'}), ({'b'}, {'b'}), ({'c'}, {'c'})]
#
# Before pairs:
# [({'b'}, {'a'}), ({'c'}, {'a'}), ({'c'}, {'b'})]
#
# Maximal pairs:
# [({'a'}, {'b'}), ({'a'}, {'c'}), ({'b'}, {'c'})]

# %%
get_log_output(logs, 'L12')
# Out:
# L12: [('a', 'c', 'e'), ('b', 'c', 'e'), ('a', 'c', 'd')]
#
#    a  b  c  d  e
# a  #  #  →  #  #
# b  #  #  →  #  #
# c  ←  ←  #  →  →
# d  #  #  ←  #  #
# e  #  #  ←  #  #
#
# Following pairs:
# [({'c'}, {'d'}), ({'a'}, {'c'}), ({'b'}, {'c'}), ({'c'}, {'e'})]
#
# Parallel pairs:
# []
#
# Sequential pairs:
# [({'c'}, {'d'}), ({'a'}, {'c'}), ({'b'}, {'c'}), ({'c'}, {'e'})]
#
# Not following pairs:
# [({'a'}, {'a'}), ({'a'}, {'b'}), ({'a'}, {'d'}), ({'a'}, {'e'}), ({'b'}, {'a'}), ({'b'}, {'b'}), ({'b'}, {'d'}), ({'b'}, {'e'}), ({'c'}, {'c'}), ({'d'}, {'a'}), ({'d'}, {'b'}), ({'d'}, {'d'}), ({'d'}, {'e'}), ({'e'}, {'a'}), ({'e'}, {'b'}), ({'e'}, {'d'}), ({'e'}, {'e'})]
#
# Before pairs:
# [({'c'}, {'a'}), ({'c'}, {'b'}), ({'d'}, {'c'}), ({'e'}, {'c'})]
#
# Maximal pairs:
# [({'c'}, {'d', 'e'}), ({'b', 'a'}, {'c'})]
