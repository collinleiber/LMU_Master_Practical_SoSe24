# %% [markdown]
# # Alpha Miner Algorithm - Playground

# %%
import pandas as pd
# %load_ext autoreload
# %autoreload 2

import pandas
import pm4py
from practical.ProcessMining.task2.alphaminer import AlphaMiner

def import_csv(file_path):
    event_log = pandas.read_csv(file_path, sep=';')
    event_log = pm4py.format_dataframe(event_log, case_id='case_id', activity_key='activity', timestamp_key='timestamp')
    return event_log

def import_xes(file_path):
    event_log = pm4py.read_xes(file_path)
    return event_log

def printPairs(pairs, alphabet):
    output = []
    for pair in pairs:
        output.append((alphabet.get(pair[0]), alphabet.get(pair[1])))
    print(sorted(output))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
 import_csv("example_files/running-example.csv")
# Out:
#     case_id            activity                 timestamp  costs resource  \
# 0         1  examine thoroughly 2010-12-31 09:06:00+00:00    400      Sue
# 1         1        check ticket 2011-01-05 14:12:00+00:00    100     Mike
# 2         1              decide 2011-01-06 10:18:00+00:00    200     Sara
# 3         1      reject request 2011-01-07 13:24:00+00:00    200     Pete
# 4         1    register request 2012-12-30 10:02:00+00:00     50     Pete
# 5         2    register request 2010-12-30 10:32:00+00:00     50     Mike
# 6         2        check ticket 2010-12-30 11:12:00+00:00    100     Mike
# 7         2    examine casually 2010-12-30 13:16:00+00:00    400     Sean
# 8         2              decide 2011-01-05 10:22:00+00:00    200     Sara
# 9         2    pay compensation 2011-01-08 11:05:00+00:00    200    Ellen
# 10        3    register request 2010-12-30 13:32:00+00:00     50     Pete
# 11        3    examine casually 2010-12-30 14:06:00+00:00    400     Mike
# ...

# %%
import_xes("example_files/running-example.xes")
# Out:
# parsing log, completed traces ::   0%|          | 0/6 [00:00<?, ?it/s]
#           concept:name            time:timestamp  cost:total org:resource  \
# 0     register request 2010-12-30 11:02:00+00:00          50         Pete
# 1   examine thoroughly 2010-12-31 10:06:00+00:00         400          Sue
# 2         check ticket 2011-01-05 15:12:00+00:00         100         Mike
# 3               decide 2011-01-06 11:18:00+00:00         200         Sara
# 4       reject request 2011-01-07 14:24:00+00:00         200         Pete
# 5     register request 2010-12-30 11:32:00+00:00          50         Mike
# 6         check ticket 2010-12-30 12:12:00+00:00         100         Mike
# 7     examine casually 2010-12-30 14:16:00+00:00         400         Sean
# 8               decide 2011-01-05 11:22:00+00:00         200         Sara
# 9     pay compensation 2011-01-08 12:05:00+00:00         200        Ellen
# 10    register request 2010-12-30 14:32:00+00:00          50         Pete
# ...

# %%
miner1 = AlphaMiner("example_files/running-example.csv")
miner1.activities
# Out:
# {0: 'examine thoroughly',
#  1: 'check ticket',
#  2: 'decide',
#  3: 'reject request',
#  4: 'register request',
#  5: 'examine casually',
#  6: 'pay compensation',
#  7: 'reinitiate request'}

# %%
miner1.event_log
# Out:
#    case_id            activity  activity_id
# 0        1  examine thoroughly            0
# 1        1        check ticket            1
# 2        1              decide            2
# 3        1      reject request            3
# 4        1    register request            4
# 5        2    register request            4
# 6        2        check ticket            1
# 7        2    examine casually            5
# 8        2              decide            2
# 9        2    pay compensation            6
# 10       3    register request            4
# 11       3    examine casually            5
# 12       3        check ticket            1
# 13       3              decide            2
# 14       3  reinitiate request            7
# 15       3  examine thoroughly            0
# 16       3        check ticket            1
# 17       3              decide            2
# 18       3    pay compensation            6
# 19       4    register request            4
# ...

# %%
miner1.traces
# Out:
# array([array([0, 1, 2, 3, 4]), array([4, 1, 5, 2, 6]),
#        array([4, 5, 1, 2, 7, 0, 1, 2, 6]), array([4, 1, 0, 2, 3]),
#        array([4, 5, 1, 2, 7, 1, 5, 2, 7, 5, 1, 2, 3]),
#        array([4, 5, 1, 2, 6])], dtype=object)

# %%
printPairs(miner1.following_pairs, miner1.activities)
# Out:
# [('check ticket', 'decide'), ('check ticket', 'examine casually'), ('check ticket', 'examine thoroughly'), ('decide', 'pay compensation'), ('decide', 'reinitiate request'), ('decide', 'reject request'), ('examine casually', 'check ticket'), ('examine casually', 'decide'), ('examine thoroughly', 'check ticket'), ('examine thoroughly', 'decide'), ('register request', 'check ticket'), ('register request', 'examine casually'), ('reinitiate request', 'check ticket'), ('reinitiate request', 'examine thoroughly'), ('reject request', 'register request')]

# %%
printPairs(miner1.parallel_pairs, miner1.activities)
# Out:
# [('check ticket', 'examine casually'), ('check ticket', 'examine thoroughly'), ('examine casually', 'check ticket'), ('examine thoroughly', 'check ticket')]

# %%
printPairs(miner1.sequential_pairs, miner1.activities)
# Out:
# [('check ticket', 'decide'), ('decide', 'pay compensation'), ('decide', 'reinitiate request'), ('decide', 'reject request'), ('examine casually', 'decide'), ('examine thoroughly', 'decide'), ('register request', 'check ticket'), ('register request', 'examine casually'), ('reinitiate request', 'check ticket'), ('reinitiate request', 'examine thoroughly'), ('reject request', 'register request')]

# %%
printPairs(miner1.not_following_pairs, miner1.activities)
# Out:
# [('check ticket', 'check ticket'), ('check ticket', 'pay compensation'), ('check ticket', 'reject request'), ('decide', 'decide'), ('decide', 'register request'), ('examine casually', 'examine casually'), ('examine casually', 'examine thoroughly'), ('examine casually', 'pay compensation'), ('examine casually', 'reinitiate request'), ('examine casually', 'reject request'), ('examine thoroughly', 'examine casually'), ('examine thoroughly', 'examine thoroughly'), ('examine thoroughly', 'pay compensation'), ('examine thoroughly', 'register request'), ('examine thoroughly', 'reject request'), ('pay compensation', 'check ticket'), ('pay compensation', 'examine casually'), ('pay compensation', 'examine thoroughly'), ('pay compensation', 'pay compensation'), ('pay compensation', 'register request'), ('pay compensation', 'reinitiate request'), ('pay compensation', 'reject request'), ('register request', 'decide'), ('register request', 'examine thoroughly'), ('register request', 'pay compensat
# ...

# %%
miner1.footprint_matrix()
# Out:
#                    check ticket decide examine casually examine thoroughly  \
# check ticket                  #      →               ||                 ||
# decide                        ←      #                ←                  ←
# examine casually             ||      →                #                  #
# examine thoroughly           ||      →                #                  #
# pay compensation              #      ←                #                  #
# register request              →      #                →                  #
# reinitiate request            →      ←                #                  →
# reject request                #      ←                #                  #
#
#                    pay compensation register request reinitiate request  \
# check ticket                      #                ←                  ←
# decide                            →                #                  →
# examine casually                  #                ←                  #
# ...

# %%
miner2 = AlphaMiner("example_files/slides-example.csv")
miner2.activities
# Out:
# {0: 'a', 1: 'c', 2: 'd', 3: 'b'}

# %%
miner2.event_log
# Out:
#    case_id activity  activity_id
# 0        1        a            0
# 1        1        c            1
# 2        1        d            2
# 3       10        b            3
# 4       10        d            2
# 5       10        c            1
# 6       11        b            3
# 7       11        d            2
# 8       11        c            1
# 9        2        a            0
# 10       2        c            1
# 11       2        d            2
# 12       3        a            0
# 13       3        c            1
# 14       3        d            2
# 15       4        a            0
# 16       4        d            2
# 17       4        c            1
# 18       5        a            0
# 19       5        d            2
# 20       5        c            1
# 21       6        b            3
# 22       6        c            1
# 23       6        d            2
# 24       7        b            3
# 25       7        c            1
# 26       7        d            2
# ...

# %%
miner2.traces
# Out:
# array([array([0, 1, 2]), array([3, 2, 1]), array([3, 2, 1]),
#        array([0, 1, 2]), array([0, 1, 2]), array([0, 2, 1]),
#        array([0, 2, 1]), array([3, 1, 2]), array([3, 1, 2]),
#        array([3, 2, 1]), array([3, 2, 1])], dtype=object)

# %%
printPairs(miner2.following_pairs, miner2.activities)
# Out:
# [('a', 'c'), ('a', 'd'), ('b', 'c'), ('b', 'd'), ('c', 'd'), ('d', 'c')]

# %%
printPairs(miner2.parallel_pairs, miner2.activities)
# Out:
# [('c', 'd'), ('d', 'c')]

# %%
printPairs(miner2.sequential_pairs, miner2.activities)
# Out:
# [('a', 'c'), ('a', 'd'), ('b', 'c'), ('b', 'd')]

# %%
printPairs(miner2.not_following_pairs, miner2.activities)
# Out:
# [('a', 'a'), ('a', 'b'), ('b', 'a'), ('b', 'b'), ('c', 'c'), ('d', 'd')]

# %%
print(miner2.footprint_matrix())
# Out:
#    a  b   c   d
# a  #  #   →   →
# b  #  #   →   →
# c  ←  ←   #  ||
# d  ←  ←  ||   #
